# %%
1+1

# %%
x = 1
y = 2

# %% [markdown]
# $x(y+1)$

# %%
x * (y+1)

# %%
x = 1
y = 3
x = y
x = 3
print(y)
# Out:
# 3

# %%
import math

def sqrt(N) :
    return math.sqrt(N)

def compute_current(power, resistance) :
    current = sqrt(power / resistance)
    return current

I1 = compute_current(3, 7)

I2 = compute_current(-4, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       8     return current
#      10 I1 = compute_current(3, 7)
# ---> 12 I2 = compute_current(-4, 2)
#
# Cell In[1], line 7, in compute_current(power, resistance)
#       6 def compute_current(power, resistance) :
# ----> 7     current = sqrt(power / resistance)
#       8     return current
#
# Cell In[1], line 4, in sqrt(N)
#       3 def sqrt(N) :
# ----> 4     return math.sqrt(N)
#
# ValueError: math domain error

# %%
# %debug
# Out:
# > /tmp/ipykernel_478/4277545724.py(4)sqrt()
#       2
#       3 def sqrt(N) :
# ----> 4     return math.sqrt(N)
#       5
#       6 def compute_current(power, resistance) :
# ipdb>  N
# -2.0
# ipdb>  up
# > /tmp/ipykernel_478/4277545724.py(7)compute_current()
#       5
#       6 def compute_current(power, resistance) :
# ----> 7     current = sqrt(power / resistance)
#       8     return current
#       9
# ipdb>  power
# -4
# ipdb>  resistance
# 2
# ipdb>  power/resistance
# -2.0
# ipdb>  up
# > /tmp/ipykernel_478/4277545724.py(12)<module>()
#       8     return current
#       9
#      10 I1 = compute_current(3, 7)
#      11
# ---> 12 I2 = compute_current(-4, 2)
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/opt/conda/lib/python3.11/bdb.py", line 361, in set_quit
#     sys.settrace(None)
#
#
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/opt/conda/lib/python3.11/site-packages/IPython/core/debugger.py", line 1086, in cmdloop
#     sys.settrace(None)
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user

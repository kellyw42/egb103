# %%
import  pandas

# %%
# Load some cycling data from Strava as as example
rides = pandas.read_csv('Strava2021.csv', parse_dates=['start_time'])
rides
# Out:
#              start_time                                               name  \
# 0   2021-02-01 19:35:00                             Pedalheads 100 special
# 1   2021-04-01 19:10:00          Return to Hack's Samford Gentleman's ride
# 2   2021-05-01 19:30:00                                       Morning Ride
# 3   2021-07-01 19:21:00                                       Morning Ride
# 4   2021-11-01 19:11:00                                       Morning Ride
# ..                  ...                                                ...
# 205 2021-12-26 22:30:00      Zwift - Dutch Diesel Cycling Starter Ride (C)
# 206 2021-12-27 01:30:00                       Zwift - OTR Tempo Group Ride
# 207 2021-12-27 19:00:00  Zwift - Rapha Festive 500 Group Ride Led By Et...
# 208 2021-12-28 19:00:00                                       Morning Ride
# 209 2021-12-30 19:30:00                                          Hacks NYE
#
#      distance  moving_time  elevation  average_watts  max_speed
# 0       102.0         3.18      441.0          188.0       54.3
# 1        46.9         1.66      733.6          193.0       66.9
# 2        34.5         1.09      136.0          184.0       51.8
# 3        33.8         0.98      121.0          226.0       55.0
# 4        49.3         1.76      718.0          184.0       68.7
# ..        ...          ...        ...            ...        ...
# 205      60.3         1.52       89.0          177.0       46.1
# 206      30.1         0.88      341.0          203.0       66.1
# 207      60.1         1.61      323.0          185.0       77.0
# 208      86.9         2.96      472.0          158.0       58.3
# 209      63.1         2.17      456.0          157.0       69.7
#
# [210 rows x 7 columns]

# %%
# Compute a new column named avg_speed based on existing columns distance and moving_time
rides['avg_speed'] = rides.distance / rides.moving_time

# %%
rides
# Out:
#              start_time                                               name  \
# 0   2021-02-01 19:35:00                             Pedalheads 100 special
# 1   2021-04-01 19:10:00          Return to Hack's Samford Gentleman's ride
# 2   2021-05-01 19:30:00                                       Morning Ride
# 3   2021-07-01 19:21:00                                       Morning Ride
# 4   2021-11-01 19:11:00                                       Morning Ride
# ..                  ...                                                ...
# 205 2021-12-26 22:30:00      Zwift - Dutch Diesel Cycling Starter Ride (C)
# 206 2021-12-27 01:30:00                       Zwift - OTR Tempo Group Ride
# 207 2021-12-27 19:00:00  Zwift - Rapha Festive 500 Group Ride Led By Et...
# 208 2021-12-28 19:00:00                                       Morning Ride
# 209 2021-12-30 19:30:00                                          Hacks NYE
#
#      distance  moving_time  elevation  average_watts  max_speed  avg_speed
# 0       102.0         3.18      441.0          188.0       54.3  32.075472
# 1        46.9         1.66      733.6          193.0       66.9  28.253012
# 2        34.5         1.09      136.0          184.0       51.8  31.651376
# 3        33.8         0.98      121.0          226.0       55.0  34.489796
# 4        49.3         1.76      718.0          184.0       68.7  28.011364
# ..        ...          ...        ...            ...        ...        ...
# 205      60.3         1.52       89.0          177.0       46.1  39.671053
# 206      30.1         0.88      341.0          203.0       66.1  34.204545
# 207      60.1         1.61      323.0          185.0       77.0  37.329193
# 208      86.9         2.96      472.0          158.0       58.3  29.358108
# 209      63.1         2.17      456.0          157.0       69.7  29.078341
#
# [210 rows x 8 columns]

# %%
# We want to study the ride data in relation to the weather on that day, so we load a separate data set from the Bureau of Meteorology
bom = pandas.read_csv('BrisbaneDailyWeather.csv')
bom
# Out:
#       year  month  day  MinTemp  MaxTemp  Rainfall
# 0     2022      2   13     18.6     29.3       7.2
# 1     2022      2   12     20.4     28.9       0.0
# 2     2022      2   11     19.1     31.3       0.0
# 3     2022      2   10     19.4     31.2       0.0
# 4     2022      2    9     18.6     30.0       0.0
# ...    ...    ...  ...      ...      ...       ...
# 8440  1999      1    5      NaN      NaN       NaN
# 8441  1999      1    4      NaN      NaN       NaN
# 8442  1999      1    3      NaN      NaN       NaN
# 8443  1999      1    2      NaN      NaN       NaN
# 8444  1999      1    1      NaN      NaN       NaN
#
# [8445 rows x 6 columns]

# %%
# In order to join with the cycling data, we first need to compute a new date column (or index column in this example)
bom.index = pandas.to_datetime(bom[['year','month','day']])
bom
# Out:
#             year  month  day  MinTemp  MaxTemp  Rainfall
# 2022-02-13  2022      2   13     18.6     29.3       7.2
# 2022-02-12  2022      2   12     20.4     28.9       0.0
# 2022-02-11  2022      2   11     19.1     31.3       0.0
# 2022-02-10  2022      2   10     19.4     31.2       0.0
# 2022-02-09  2022      2    9     18.6     30.0       0.0
# ...          ...    ...  ...      ...      ...       ...
# 1999-01-05  1999      1    5      NaN      NaN       NaN
# 1999-01-04  1999      1    4      NaN      NaN       NaN
# 1999-01-03  1999      1    3      NaN      NaN       NaN
# 1999-01-02  1999      1    2      NaN      NaN       NaN
# 1999-01-01  1999      1    1      NaN      NaN       NaN
#
# [8445 rows x 6 columns]

# %%
# Retrieve just the columns we are interested in
bom[['MinTemp', 'MaxTemp', 'Rainfall']]
# Out:
#             MinTemp  MaxTemp  Rainfall
# 2022-02-13     18.6     29.3       7.2
# 2022-02-12     20.4     28.9       0.0
# 2022-02-11     19.1     31.3       0.0
# 2022-02-10     19.4     31.2       0.0
# 2022-02-09     18.6     30.0       0.0
# ...             ...      ...       ...
# 1999-01-05      NaN      NaN       NaN
# 1999-01-04      NaN      NaN       NaN
# 1999-01-03      NaN      NaN       NaN
# 1999-01-02      NaN      NaN       NaN
# 1999-01-01      NaN      NaN       NaN
#
# [8445 rows x 3 columns]

# %%
# Update the bom data frame to include only the columns we are interested in (plus the existing date index)
bom = bom[['MinTemp', 'MaxTemp', 'Rainfall']]
bom
# Out:
#             MinTemp  MaxTemp  Rainfall
# 2022-02-13     18.6     29.3       7.2
# 2022-02-12     20.4     28.9       0.0
# 2022-02-11     19.1     31.3       0.0
# 2022-02-10     19.4     31.2       0.0
# 2022-02-09     18.6     30.0       0.0
# ...             ...      ...       ...
# 1999-01-05      NaN      NaN       NaN
# 1999-01-04      NaN      NaN       NaN
# 1999-01-03      NaN      NaN       NaN
# 1999-01-02      NaN      NaN       NaN
# 1999-01-01      NaN      NaN       NaN
#
# [8445 rows x 3 columns]

# %%
# To like the ride data to the BOM data, we need a date column in the ride data frame
rides['start_date'] = rides.start_time.dt.date
rides
# Out:
#              start_time                                               name  \
# 0   2021-02-01 19:35:00                             Pedalheads 100 special
# 1   2021-04-01 19:10:00          Return to Hack's Samford Gentleman's ride
# 2   2021-05-01 19:30:00                                       Morning Ride
# 3   2021-07-01 19:21:00                                       Morning Ride
# 4   2021-11-01 19:11:00                                       Morning Ride
# ..                  ...                                                ...
# 205 2021-12-26 22:30:00      Zwift - Dutch Diesel Cycling Starter Ride (C)
# 206 2021-12-27 01:30:00                       Zwift - OTR Tempo Group Ride
# 207 2021-12-27 19:00:00  Zwift - Rapha Festive 500 Group Ride Led By Et...
# 208 2021-12-28 19:00:00                                       Morning Ride
# 209 2021-12-30 19:30:00                                          Hacks NYE
#
#      distance  moving_time  elevation  average_watts  max_speed  avg_speed  \
# 0       102.0         3.18      441.0          188.0       54.3  32.075472
# 1        46.9         1.66      733.6          193.0       66.9  28.253012
# 2        34.5         1.09      136.0          184.0       51.8  31.651376
# 3        33.8         0.98      121.0          226.0       55.0  34.489796
# 4        49.3         1.76      718.0          184.0       68.7  28.011364
# ..        ...          ...        ...            ...        ...        ...
# 205      60.3         1.52       89.0          177.0       46.1  39.671053
# 206      30.1         0.88      341.0          203.0       66.1  34.204545
# 207      60.1         1.61      323.0          185.0       77.0  37.329193
# 208      86.9         2.96      472.0          158.0       58.3  29.358108
# 209      63.1         2.17      456.0          157.0       69.7  29.078341
#
#      start_date
# 0    2021-02-01
# 1    2021-04-01
# 2    2021-05-01
# 3    2021-07-01
# 4    2021-11-01
# ..          ...
# 205  2021-12-26
# 206  2021-12-27
# 207  2021-12-27
# 208  2021-12-28
# 209  2021-12-30
#
# [210 rows x 9 columns]

# %%
# This seems correct, but if we look more carefully we see the values in the start_date column are actually of type object (i.e. strings, and not dates)
rides.start_date
# Out:
# 0      2021-02-01
# 1      2021-04-01
# 2      2021-05-01
# 3      2021-07-01
# 4      2021-11-01
#           ...
# 205    2021-12-26
# 206    2021-12-27
# 207    2021-12-27
# 208    2021-12-28
# 209    2021-12-30
# Name: start_date, Length: 210, dtype: object

# %%
# Compare this to the bom data were the values in the index column are of type datetime64
bom.index
# Out:
# DatetimeIndex(['2022-02-13', '2022-02-12', '2022-02-11', '2022-02-10',
#                '2022-02-09', '2022-02-08', '2022-02-07', '2022-02-06',
#                '2022-02-05', '2022-02-04',
#                ...
#                '1999-01-10', '1999-01-09', '1999-01-08', '1999-01-07',
#                '1999-01-06', '1999-01-05', '1999-01-04', '1999-01-03',
#                '1999-01-02', '1999-01-01'],
#               dtype='datetime64[ns]', length=8445, freq=None)

# %%
# After a quick Google search, we discover the normalize() method will convert a date time value into just a date value (with the appropriate data type)
rides['start_date'] = rides.start_time.dt.normalize()
rides
# Out:
#              start_time                                               name  \
# 0   2021-02-01 19:35:00                             Pedalheads 100 special
# 1   2021-04-01 19:10:00          Return to Hack's Samford Gentleman's ride
# 2   2021-05-01 19:30:00                                       Morning Ride
# 3   2021-07-01 19:21:00                                       Morning Ride
# 4   2021-11-01 19:11:00                                       Morning Ride
# ..                  ...                                                ...
# 205 2021-12-26 22:30:00      Zwift - Dutch Diesel Cycling Starter Ride (C)
# 206 2021-12-27 01:30:00                       Zwift - OTR Tempo Group Ride
# 207 2021-12-27 19:00:00  Zwift - Rapha Festive 500 Group Ride Led By Et...
# 208 2021-12-28 19:00:00                                       Morning Ride
# 209 2021-12-30 19:30:00                                          Hacks NYE
#
#      distance  moving_time  elevation  average_watts  max_speed  avg_speed  \
# 0       102.0         3.18      441.0          188.0       54.3  32.075472
# 1        46.9         1.66      733.6          193.0       66.9  28.253012
# 2        34.5         1.09      136.0          184.0       51.8  31.651376
# 3        33.8         0.98      121.0          226.0       55.0  34.489796
# 4        49.3         1.76      718.0          184.0       68.7  28.011364
# ..        ...          ...        ...            ...        ...        ...
# 205      60.3         1.52       89.0          177.0       46.1  39.671053
# 206      30.1         0.88      341.0          203.0       66.1  34.204545
# 207      60.1         1.61      323.0          185.0       77.0  37.329193
# 208      86.9         2.96      472.0          158.0       58.3  29.358108
# 209      63.1         2.17      456.0          157.0       69.7  29.078341
#
#     start_date
# 0   2021-02-01
# 1   2021-04-01
# 2   2021-05-01
# 3   2021-07-01
# 4   2021-11-01
# ..         ...
# 205 2021-12-26
# 206 2021-12-27
# 207 2021-12-27
# 208 2021-12-28
# 209 2021-12-30
#
# [210 rows x 9 columns]

# %%
# The values in the start_date column are now of type datetime64 (which will allow us to match them with corresponding values in the BOM data)
rides.start_date
# Out:
# 0     2021-02-01
# 1     2021-04-01
# 2     2021-05-01
# 3     2021-07-01
# 4     2021-11-01
#          ...
# 205   2021-12-26
# 206   2021-12-27
# 207   2021-12-27
# 208   2021-12-28
# 209   2021-12-30
# Name: start_date, Length: 210, dtype: datetime64[ns]

# %%
# Finally we are able to join data from the rides data with corresponding rows from the BOM data 
# i.e. where the start_date column of the rides is equal to the index of the bom 
rides.join(bom, on = 'start_date')
# Out:
#              start_time                                               name  \
# 0   2021-02-01 19:35:00                             Pedalheads 100 special
# 1   2021-04-01 19:10:00          Return to Hack's Samford Gentleman's ride
# 2   2021-05-01 19:30:00                                       Morning Ride
# 3   2021-07-01 19:21:00                                       Morning Ride
# 4   2021-11-01 19:11:00                                       Morning Ride
# ..                  ...                                                ...
# 205 2021-12-26 22:30:00      Zwift - Dutch Diesel Cycling Starter Ride (C)
# 206 2021-12-27 01:30:00                       Zwift - OTR Tempo Group Ride
# 207 2021-12-27 19:00:00  Zwift - Rapha Festive 500 Group Ride Led By Et...
# 208 2021-12-28 19:00:00                                       Morning Ride
# 209 2021-12-30 19:30:00                                          Hacks NYE
#
#      distance  moving_time  elevation  average_watts  max_speed  avg_speed  \
# 0       102.0         3.18      441.0          188.0       54.3  32.075472
# 1        46.9         1.66      733.6          193.0       66.9  28.253012
# 2        34.5         1.09      136.0          184.0       51.8  31.651376
# 3        33.8         0.98      121.0          226.0       55.0  34.489796
# 4        49.3         1.76      718.0          184.0       68.7  28.011364
# ..        ...          ...        ...            ...        ...        ...
# 205      60.3         1.52       89.0          177.0       46.1  39.671053
# 206      30.1         0.88      341.0          203.0       66.1  34.204545
# 207      60.1         1.61      323.0          185.0       77.0  37.329193
# 208      86.9         2.96      472.0          158.0       58.3  29.358108
# 209      63.1         2.17      456.0          157.0       69.7  29.078341
#
#     start_date  MinTemp  MaxTemp  Rainfall
# 0   2021-02-01     22.5     29.7       1.4
# 1   2021-04-01     18.0     26.2       0.0
# 2   2021-05-01     16.7     22.3       6.2
# 3   2021-07-01     11.9     20.5       7.0
# 4   2021-11-01     16.0     24.1       0.0
# ..         ...      ...      ...       ...
# 205 2021-12-26     20.8     28.4       7.6
# 206 2021-12-27     21.3     28.9       0.0
# 207 2021-12-27     21.3     28.9       0.0
# 208 2021-12-28     19.6     25.7      14.6
# 209 2021-12-30     17.8     27.7       0.0
#
# [210 rows x 12 columns]

# %%
# If instead of matching with the index of the bom, we wish to match some other column, we can instead use the merge method to 
# join based on an arbitary column of the rides data equal to some arbitrary column of the bom data.
# Here we are matching the avg_speed of the ride with the MaxTemp on that day (which doesn't necessarily make a great deal of sense).
# Notice that rows from each data set may be include more than once in the merged data set since it combines all rows from the 
# first data frame with all rows from the second data frame that have matching column values.
rides.merge(bom, left_on = 'avg_speed', right_on='MaxTemp')
# Out:
#              start_time                                      name  distance  \
# 0   2021-01-19 19:29:00                              Morning Ride      30.6
# 1   2021-01-19 19:29:00                              Morning Ride      30.6
# 2   2021-01-19 19:29:00                              Morning Ride      30.6
# 3   2021-01-19 19:29:00                              Morning Ride      30.6
# 4   2021-01-19 19:29:00                              Morning Ride      30.6
# ..                  ...                                       ...       ...
# 587 2021-02-10 19:33:00                              Morning Ride      61.2
# 588 2021-02-10 19:33:00                              Morning Ride      61.2
# 589 2021-02-10 19:33:00                              Morning Ride      61.2
# 590 2021-02-10 19:33:00                              Morning Ride      61.2
# 591 2021-11-30 20:00:00  Telstra Connected Cycling Group Ride (C)      28.5
#
#      moving_time  elevation  average_watts  max_speed  avg_speed start_date  \
# 0           1.00      139.0          176.0       48.9       30.6 2021-01-19
# 1           1.00      139.0          176.0       48.9       30.6 2021-01-19
# 2           1.00      139.0          176.0       48.9       30.6 2021-01-19
# 3           1.00      139.0          176.0       48.9       30.6 2021-01-19
# 4           1.00      139.0          176.0       48.9       30.6 2021-01-19
# ..           ...        ...            ...        ...        ...        ...
# 587         1.80      207.0          205.0       50.4       34.0 2021-02-10
# 588         1.80      207.0          205.0       50.4       34.0 2021-02-10
# 589         1.80      207.0          205.0       50.4       34.0 2021-02-10
# 590         1.80      207.0          205.0       50.4       34.0 2021-02-10
# 591         0.76      133.0          194.0       53.8       37.5 2021-11-30
#
#      MinTemp  MaxTemp  Rainfall
# 0       18.3     30.6       0.0
# 1       20.8     30.6       0.0
# 2       23.0     30.6       0.4
# 3       19.4     30.6       0.0
# 4       24.1     30.6       0.0
# ..       ...      ...       ...
# 587     21.0     34.0       0.0
# 588     24.0     34.0       0.0
# 589     25.0     34.0       0.0
# 590     19.0     34.0       0.0
# 591     24.2     37.5       0.2
#
# [592 rows x 12 columns]

# %%
# Try creating some joining examples of your own ...

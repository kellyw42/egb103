# %%
import pandas

weather = pandas.read_csv('BrisbaneWeather.csv')
weather
# Out:
#         Month  MinTemp  MaxTemp     Rainfall
# 0         NaN  Celcius  Celcius  Millimetres
# 1     January     20.7     29.4        159.6
# 2    February     20.6       29        158.3
# 3       March     19.4       28        140.7
# 4       April     16.6     26.1         92.5
# 5         May     13.3     23.2         73.7
# 6        June     10.9     20.9         67.8
# 7        July      9.5     20.4         56.5
# 8      August     10.3     21.8         45.9
# 9   September     12.9       24         45.7
# 10    October     15.8     26.1         75.4
# 11   November     18.1     27.8           97
# 12   December     19.8     29.1        133.3

# %%
# The above looks OK, but if we look carefully at the types of our columns, they all contain values of type object (i.e. strings and not numbers)
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     12 non-null     object
#  1   MinTemp   13 non-null     object
#  2   MaxTemp   13 non-null     object
#  3   Rainfall  13 non-null     object
# dtypes: object(4)
# memory usage: 544.0+ bytes

# %%
# As a consequence, we can't compute the mean of the Rainfall column (because they are not numbers)
weather.Rainfall.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'Millimetres159.6158.3140.792.573.767.856.545.945.775.497133.3'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:1626, in _ensure_numeric(x)
#    1625 try:
# -> 1626     x = complex(x)
#    1627 except ValueError as err:
#    1628     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 # As a consequence, we can't compute the mean of the Rainfall column (because they are not numbers)
# ----> 2 weather.Rainfall.mean()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py:11124, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11106 @doc(
#   11107     _num_doc,
#   11108     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11122     **kwargs,
#   11123 ):
# > 11124     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py:10694, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10686 def mean(
#   10687     self,
#   10688     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10692     **kwargs,
#   10693 ) -> Series | float:
# > 10694     return self._stat_function(
#   10695         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10696     )
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py:10646, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10636     warnings.warn(
#   10637         "Using the level keyword in DataFrame and Series aggregations is "
#   10638         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10641         stacklevel=find_stack_level(),
#   10642     )
#   10643     return self._agg_by_level(
#   10644         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10645     )
# > 10646 return self._reduce(
#   10647     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10648 )
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:698, in nanmean(values, axis, skipna, mask)
#     695     dtype_count = dtype
#     697 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     700 if axis is not None and getattr(the_sum, "ndim", False):
#     701     count = cast(np.ndarray, count)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/nanops.py:1629, in _ensure_numeric(x)
#    1626             x = complex(x)
#    1627         except ValueError as err:
#    1628             # e.g. "foo"
# -> 1629             raise TypeError(f"Could not convert {x} to numeric") from err
#    1630 return x
#
# TypeError: Could not convert Millimetres159.6158.3140.792.573.767.856.545.945.775.497133.3 to numeric

# %%
# We see, for example that the Rainfall on June is the string '67.8'
weather.loc[6,'Rainfall']
# Out:
# '67.8'

# %%
# which is of type string
type(weather.loc[6,'Rainfall'])
# Out:
# str

# %%
# The cause of the problem in this example is the 2nd row that contains the units (Celcius and Millimetres) rather than actual data values.
# So, the simple solution for this particular example is to skip row 1 when importing the data from the csv file
weather = pandas.read_csv('BrisbaneWeather.csv', skiprows=[1])
weather
# Out:
#         Month  MinTemp  MaxTemp  Rainfall
# 0     January     20.7     29.4     159.6
# 1    February     20.6     29.0     158.3
# 2       March     19.4     28.0     140.7
# 3       April     16.6     26.1      92.5
# 4         May     13.3     23.2      73.7
# 5        June     10.9     20.9      67.8
# 6        July      9.5     20.4      56.5
# 7      August     10.3     21.8      45.9
# 8   September     12.9     24.0      45.7
# 9     October     15.8     26.1      75.4
# 10   November     18.1     27.8      97.0
# 11   December     19.8     29.1     133.3

# %%
# Which now gives us numeric types in the Rainfall column
type(weather.loc[6,'Rainfall'])
# Out:
# numpy.float64

# %%
# However, if the error(s) were spread over many rows, then we'd need a different approach.
# Our first attempt is to tell pandas to try to convert all values to type float
# In this example it fails because the string 'January' can't be implicitly converted to a float
weather = pandas.read_csv('BrisbaneWeather.csv', dtype=float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1113, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [9], line 4
#       1 # However, if the error(s) were spread over many rows, then we'd need a different approach.
#       2 # Our first attempt is to tell pandas to try to convert all values to type float
#       3 # In this example it fails because the string 'January' can't be implicitly converted to a float
# ----> 4 weather = pandas.read_csv('BrisbaneWeather.csv', dtype=float)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:883, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1026, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: could not convert string to float: 'January'

# %%
# Let's instead only try to convert the Rainfall column to type float (by using a dictionary)
# This also fails when we try to convert the string 'Millimetres' to a float
weather = pandas.read_csv('BrisbaneWeather.csv', dtype={'Rainfall':float})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1113, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 3
#       1 # Let's instead only try to convert the Rainfall column to type float (by using a dictionary)
#       2 # This also fails when we try to convert the string 'Millimetres' to a float
# ----> 3 weather = pandas.read_csv('BrisbaneWeather.csv', dtype={'Rainfall':float})
#
# File /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:883, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1026, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1119, in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: could not convert string to float: 'Millimetres'

# %%
# We can instead create our own custom function to convert values in the  Rainfall column of the csv file
# As a very simple starting point, we'll ignore the input parameter str and just return the constant value 3.14
def my_converter(str) :
    return 3.14

# %%
# Tell pandas to use our my_converter function to convert the Rainfall column
weather = pandas.read_csv('BrisbaneWeather.csv', converters={'Rainfall': my_converter})
weather
# Out:
#         Month  MinTemp  MaxTemp  Rainfall
# 0         NaN  Celcius  Celcius      3.14
# 1     January     20.7     29.4      3.14
# 2    February     20.6       29      3.14
# 3       March     19.4       28      3.14
# 4       April     16.6     26.1      3.14
# 5         May     13.3     23.2      3.14
# 6        June     10.9     20.9      3.14
# 7        July      9.5     20.4      3.14
# 8      August     10.3     21.8      3.14
# 9   September     12.9       24      3.14
# 10    October     15.8     26.1      3.14
# 11   November     18.1     27.8      3.14
# 12   December     19.8     29.1      3.14

# %%
# Now let's replace the value 3.14 by something more sensible.
# Let's try to convert each input str value to a float
def my_converter(str) :
    return float(str)

weather = pandas.read_csv('BrisbaneWeather.csv', converters={'Rainfall': my_converter})
weather

# this fails as previously when we try to convert the string 'Millimetres' to a float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 6
#       3 def my_converter(str) :
#       4     return float(str)
# ----> 6 weather = pandas.read_csv('BrisbaneWeather.csv', converters={'Rainfall': my_converter})
#       7 weather
#
# File /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1253, in TextFileReader.read(self, nrows)
#    1251 nrows = validate_integer("nrows", nrows)
#    1252 try:
# -> 1253     index, columns, col_dict = self._engine.read(nrows)
#    1254 except Exception:
#    1255     self.close()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:883, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1005, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:2014, in pandas._libs.parsers._apply_converter()
#
# Cell In [13], line 4, in my_converter(str)
#       3 def my_converter(str) :
# ----> 4     return float(str)
#
# ValueError: could not convert string to float: 'Millimetres'

# %%
# instead we adapt our converter function to 'catch' the generated ValueError and instead return say math.nan (or any other value we choose) when a ValueError occurred
import math

def my_converter(str) :
    try :
        return float(str)
    except ValueError :
        return math.nan

weather = pandas.read_csv('BrisbaneWeather.csv', converters={'Rainfall': my_converter})
weather
# Out:
#         Month  MinTemp  MaxTemp  Rainfall
# 0         NaN  Celcius  Celcius       NaN
# 1     January     20.7     29.4     159.6
# 2    February     20.6       29     158.3
# 3       March     19.4       28     140.7
# 4       April     16.6     26.1      92.5
# 5         May     13.3     23.2      73.7
# 6        June     10.9     20.9      67.8
# 7        July      9.5     20.4      56.5
# 8      August     10.3     21.8      45.9
# 9   September     12.9       24      45.7
# 10    October     15.8     26.1      75.4
# 11   November     18.1     27.8      97.0
# 12   December     19.8     29.1     133.3

# %%
# The Rainfall in June is now a number (and not a string)
weather.loc[6,'Rainfall']
# Out:
# 67.8

# %%
type(weather.loc[6,'Rainfall'])
# Out:
# numpy.float64

# %%
# Now that all the values in the Rainfall column are numbers, we can perform arithmetic calculations such as finding the mean Rainfall.
weather.Rainfall.mean()
# Out:
# 95.53333333333332

# %%
# Or the sum of all Rainfall
weather.Rainfall.sum()
# Out:
# 1146.4

# %%
# In the above example, we performed the conversion when we read the data in from the csv file.
# An alternative approach is to read it in as type string and do the conversion later ...
weather = pandas.read_csv('BrisbaneWeather.csv')
weather
# Out:
#         Month  MinTemp  MaxTemp     Rainfall
# 0         NaN  Celcius  Celcius  Millimetres
# 1     January     20.7     29.4        159.6
# 2    February     20.6       29        158.3
# 3       March     19.4       28        140.7
# 4       April     16.6     26.1         92.5
# 5         May     13.3     23.2         73.7
# 6        June     10.9     20.9         67.8
# 7        July      9.5     20.4         56.5
# 8      August     10.3     21.8         45.9
# 9   September     12.9       24         45.7
# 10    October     15.8     26.1         75.4
# 11   November     18.1     27.8           97
# 12   December     19.8     29.1        133.3

# %%
# The to_numeric function attempts to convert a data series to be numeric values
pandas.to_numeric(weather.Rainfall)

# In this case, the convertion fails when trying to convert  the string 'Millimetres' to a numeric type
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Millimetres"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [20], line 2
#       1 # The to_numeric function attempts to convert a data series to be numeric values
# ----> 2 pandas.to_numeric(weather.Rainfall)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/tools/numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2357, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Millimetres" at position 0

# %%
# We can however, specify what to do  if an error occurs. In this example we say to coerce (or force) the value to a numeric type.
# In our example, the string value 'Millimetres' is coerced to the special numeric value NaN
pandas.to_numeric(weather.Rainfall, errors='coerce')
# Out:
# 0       NaN
# 1     159.6
# 2     158.3
# 3     140.7
# 4      92.5
# 5      73.7
# 6      67.8
# 7      56.5
# 8      45.9
# 9      45.7
# 10     75.4
# 11     97.0
# 12    133.3
# Name: Rainfall, dtype: float64

# %%
# We can then use this approach to redefine the Rainfall column (which did contain strings), to now contain these values coerced to be numeric
weather.Rainfall = pandas.to_numeric(weather.Rainfall, errors='coerce')

# %%
weather
# Out:
#         Month  MinTemp  MaxTemp  Rainfall
# 0         NaN  Celcius  Celcius       NaN
# 1     January     20.7     29.4     159.6
# 2    February     20.6       29     158.3
# 3       March     19.4       28     140.7
# 4       April     16.6     26.1      92.5
# 5         May     13.3     23.2      73.7
# 6        June     10.9     20.9      67.8
# 7        July      9.5     20.4      56.5
# 8      August     10.3     21.8      45.9
# 9   September     12.9       24      45.7
# 10    October     15.8     26.1      75.4
# 11   November     18.1     27.8      97.0
# 12   December     19.8     29.1     133.3

# %%
# We see now that the Rainfall column contains values of type float64
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     12 non-null     object
#  1   MinTemp   13 non-null     object
#  2   MaxTemp   13 non-null     object
#  3   Rainfall  12 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 544.0+ bytes

# %%
# Let's try a new example with some different types of data cleaning needed
D202 = pandas.read_csv('D202.csv')
D202
# Out:
#                  TYPE        DATE START TIME END TIME  USAGE UNITS    COST  \
# 0      Electric usage  10/22/2016       0:00     0:14   0.01   kWh  $0.00
# 1      Electric usage  10/22/2016       0:15     0:29   0.01   kWh  $0.00
# 2      Electric usage  10/22/2016       0:30     0:44   0.01   kWh  $0.00
# 3      Electric usage  10/22/2016       0:45     0:59   0.01   kWh  $0.00
# 4      Electric usage  10/22/2016       1:00     1:14   0.01   kWh  $0.00
# ...               ...         ...        ...      ...    ...   ...     ...
# 70363  Electric usage  10/24/2018      22:45    22:59   0.02   kWh  $0.00
# 70364  Electric usage  10/24/2018      23:00    23:14   0.03   kWh  $0.01
# 70365  Electric usage  10/24/2018      23:15    23:29   0.03   kWh  $0.01
# 70366  Electric usage  10/24/2018      23:30    23:44   0.03   kWh  $0.01
# 70367  Electric usage  10/24/2018      23:45    23:59   0.03   kWh  $0.01
#
#        NOTES
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 70363    NaN
# 70364    NaN
# 70365    NaN
# 70366    NaN
# 70367    NaN
#
# [70368 rows x 8 columns]

# %%
# We see in this example that the values stored in the COST column are of type object (i.e. of type string and not of a numeric type)
D202.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70368 entries, 0 to 70367
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE        70368 non-null  object
#  1   DATE        70368 non-null  object
#  2   START TIME  70368 non-null  object
#  3   END TIME    70368 non-null  object
#  4   USAGE       70368 non-null  float64
#  5   UNITS       70368 non-null  object
#  6   COST        70368 non-null  object
#  7   NOTES       0 non-null      float64
# dtypes: float64(2), object(6)
# memory usage: 4.3+ MB

# %%
# This prevents us from performing numeric calculations on the COST column
D202.COST.sum()

# %%
# The problem is the dollar signs in the COST column.
# So, we can compute a new series that replaces each dollar sign character by the empty string ''
D202.COST.str.replace('$','')
# Out:
# /tmp/ipykernel_196/922058623.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   D202.COST.str.replace('$','')
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
#          ...
# 70363    0.00
# 70364    0.01
# 70365    0.01
# 70366    0.01
# 70367    0.01
# Name: COST, Length: 70368, dtype: object

# %%
# The above output looks OK (without the dollar signs), but we see that the values are still of type object (i.e. strings and not numbers)
D202.COST.str.replace('$','').astype('float')
# Out:
# /tmp/ipykernel_196/1558687887.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   D202.COST.str.replace('$','').astype('float')
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
#          ...
# 70363    0.00
# 70364    0.01
# 70365    0.01
# 70366    0.01
# 70367    0.01
# Name: COST, Length: 70368, dtype: float64

# %%
# We can use the astype function to convert all of these string values into floats (which will work now because we have removed the dollar signs)
D202.COST = D202.COST.str.replace('$','').astype('float')
# Out:
# /tmp/ipykernel_196/295844634.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   D202.COST = D202.COST.str.replace('$','').astype('float')

# %%
# We see now that the values in the COST column are now of type float64
D202.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70368 entries, 0 to 70367
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE        70368 non-null  object
#  1   DATE        70368 non-null  object
#  2   START TIME  70368 non-null  object
#  3   END TIME    70368 non-null  object
#  4   USAGE       70368 non-null  float64
#  5   UNITS       70368 non-null  object
#  6   COST        70368 non-null  float64
#  7   NOTES       0 non-null      float64
# dtypes: float64(3), object(5)
# memory usage: 4.3+ MB

# %%
# Which allows us to perform  numeric calculations such as sum
D202.COST.sum()
# Out:
# 1736.9500000000003

# %%
# Try creating some examples of your own ...
